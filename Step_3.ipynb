# %%
import pandas as P

# %%
D = P.read_csv("Car Data.csv")

# %%
print(D.columns)
# Out:
# Index(['city_mpg', 'class', 'combination_mpg', 'cylinders', 'displacement',
#        'drive', 'fuel_type', 'highway_mpg', 'make', 'model', 'transmission',
#        'year'],
#       dtype='object')

# %%
E = D.isnull().sum()
print(E)
# Out:
# city_mpg           0
# class              0
# combination_mpg    0
# cylinders          2
# displacement       2
# drive              0
# fuel_type          0
# highway_mpg        0
# make               0
# model              0
# transmission       0
# year               0
# dtype: int64

# %%
Fill_Cylinders = D["cylinders"].fillna(D["cylinders"].mean())
print(Fill_Cylinders)
# Out:
# 0      4.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      4.0
#       ...
# 545    4.0
# 546    6.0
# 547    6.0
# 548    8.0
# 549    8.0
# Name: cylinders, Length: 550, dtype: float64

# %%
Fill_Displacement = D["displacement"].fillna(D["displacement"].mean())

# %%
print(D.columns)
# Out:
# Index(['city_mpg', 'class', 'combination_mpg', 'cylinders', 'displacement',
#        'drive', 'fuel_type', 'highway_mpg', 'make', 'model', 'transmission',
#        'year'],
#       dtype='object')

# %%
X = D.drop("combination_mpg" , axis = 1)

# %%
Y = D["combination_mpg"]

# %%
Category = X.select_dtypes(include = "object").columns

# %%
X = P.get_dummies (X , columns = Category)

# %%
from sklearn.model_selection import train_test_split

# %%
X_Train , X_Test , Y_Train , Y_Test = train_test_split(X , Y , test_size = 0.2 , random_state = 42)

# %%
print(X_Train , X_Test , Y_Train , Y_Test)
# Out:
#      city_mpg  cylinders  displacement  highway_mpg  year  class_compact car  \
# 482        27        3.0           1.5           37  2023              False
# 158        18        6.0           3.3           25  2017              False
# 15         16        8.0           5.0           25  2014              False
# 334        21        4.0           2.0           27  2020              False
# 39         21        4.0           2.0           28  2014              False
# ..        ...        ...           ...          ...   ...                ...
# 71         19        6.0           3.0           28  2015               True
# 106        18        6.0           3.3           25  2016              False
# 270        21        4.0           2.4           29  2019              False
# 435        23        4.0           2.0           33  2022              False
# 102        25        4.0           2.5           36  2016              False
#
# ...

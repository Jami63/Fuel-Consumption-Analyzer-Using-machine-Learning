# %%
import pandas as P

# %%
D = P.read_csv("Car Data.csv")

# %%
print(D.columns)
# Out:
# Index(['city_mpg', 'class', 'combination_mpg', 'cylinders', 'displacement',
#        'drive', 'fuel_type', 'highway_mpg', 'make', 'model', 'transmission',
#        'year'],
#       dtype='object')

# %%
print(D.head)
# Out:
# <bound method NDFrame.head of      city_mpg                        class  combination_mpg  cylinders  \
# 0          25                  midsize car               29        4.0
# 1          26                  midsize car               30        4.0
# 2          25  small sport utility vehicle               27        4.0
# 3          26  small sport utility vehicle               29        4.0
# 4          26  small sport utility vehicle               28        4.0
# ..        ...                          ...              ...        ...
# 545        23                  compact car               27        4.0
# 546        21                  midsize car               24        6.0
# 547        21                  midsize car               24        6.0
# 548        17                  midsize car               19        8.0
# 549        17                  midsize car               19        8.0
#
#      displacement drive fuel_type  highway_mpg   make  \
# ...

# %%
print(D.shape)
# Out:
# (550, 12)

# %%
print(D.info)
# Out:
# <bound method DataFrame.info of      city_mpg                        class  combination_mpg  cylinders  \
# 0          25                  midsize car               29        4.0
# 1          26                  midsize car               30        4.0
# 2          25  small sport utility vehicle               27        4.0
# 3          26  small sport utility vehicle               29        4.0
# 4          26  small sport utility vehicle               28        4.0
# ..        ...                          ...              ...        ...
# 545        23                  compact car               27        4.0
# 546        21                  midsize car               24        6.0
# 547        21                  midsize car               24        6.0
# 548        17                  midsize car               19        8.0
# 549        17                  midsize car               19        8.0
#
#      displacement drive fuel_type  highway_mpg   make  \
# ...

# %%
Target = D["combination_mpg"]

# %%
print(Target.head)
# Out:
# <bound method NDFrame.head of 0      29
# 1      30
# 2      27
# 3      29
# 4      28
#        ..
# 545    27
# 546    24
# 547    24
# 548    19
# 549    19
# Name: combination_mpg, Length: 550, dtype: int64>

# %%
Null_Data = D.isnull().sum ()

# %%
print(Null_Data)
# Out:
# city_mpg           0
# class              0
# combination_mpg    0
# cylinders          2
# displacement       2
# drive              0
# fuel_type          0
# highway_mpg        0
# make               0
# model              0
# transmission       0
# year               0
# dtype: int64
